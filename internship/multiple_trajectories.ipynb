# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import importlib
import codebase
from scipy.io import loadmat

# %%
data = loadmat('data/py_odes_mult_traj.mat')
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 't', 'linear_oscillator', 'cubic_oscillator', 'oscillator_3d', 'lorenz', 'mean_field', 'van_der_pol'])

# %%
for trajectory in data['linear_oscillator']:
    plt.plot(trajectory[:, 0])
plt.show()

# %%
for trajectory in data['cubic_oscillator']:
    plt.plot(trajectory[:, 0])
plt.show()

# %%
for trajectory in data['oscillator_3d']:
    plt.plot(trajectory[:, 0])
plt.show()

# %%
for trajectory in data['lorenz']:
    plt.plot(trajectory[:, 0])
plt.show()

# %%
for trajectory in data['mean_field']:
    plt.plot(trajectory[:, 0])
plt.show()

# %%
for trajectory in data['van_der_pol']:
    plt.plot(trajectory[:, 0])
plt.show()
